# %%
# %pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.2.0-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from xgboost) (1.13.1)
# Downloading xgboost-3.2.0-py3-none-macosx_12_0_arm64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 15.4 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading data

# %%
df = pd.read_csv('data/processed_data.csv')

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
print(f"Data Loaded: {df.shape} rows")
# Out:
# Data Loaded: (898000, 15) rows

# %%
df.columns
# Out:
# Index(['date', 'store', 'item', 'sales', 'product_name', 'price',
#        'current_stock', 'day_of_week', 'month', 'year', 'day_of_year',
#        'sales_lag_1', 'sales_lag_7', 'sales_lag_30', 'rolling_mean_7'],
#       dtype='object')
